# %% [markdown]
# Hello and welcome, work hard play hard

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


#import data from Wharton into a variable 
car_data = pd.read_excel('data_daimler_volkswagen.xlsx', index_col = 5)

#This is what the top of our data file looks like. 
#We got some columns that we do not nead, so the next step will be to clean it up.
car_data.head()
# Out:
#                     Global Company Key Industry Format Data Format  \
# Data Year - Fiscal
# 2000                             17828            INDL    HIST_STD
# 2001                             17828            INDL    HIST_STD
# 2002                             17828            INDL    HIST_STD
# 2003                             17828            INDL    HIST_STD
# 2004                             17828            INDL    HIST_STD
#
#                    Level of Consolidation - Company Annual Descriptor  \
# Data Year - Fiscal
# 2000                                                                C
# 2001                                                                C
# 2002                                                                C
# 2003                                                                C
# 2004                                                                C
#
#                    Population Source  Data Date  Assets - Total  \
# Data Year - Fiscal
# 2000                               I   20001231          199274
# 2001                               I   20011231          207410
# 2002                               I   20021231          187327
# 2003                               I   20031231          178268
# 2004                               I   20041231          182696
#
#                     Earnings Before Interest  \
# Data Year - Fiscal
# 2000                                 17778.0
# 2001                                 12984.0
# 2002                                 17655.0
# 2003                                 15480.0
# 2004                                 15775.0
#
#                     Income Before Extraordinary Items  Revenue - Total  \
# Data Year - Fiscal
# 2000                                             2465           162384
# 2001                                             -662           152873
# 2002                                             4877           149583
# 2003                                             -418           136437
# 2004                                             2466           142059
#
#                     Stockholders Equity - Parent  \
# Data Year - Fiscal
# 2000                                       42409
# 2001                                       39004
# 2002                                       34914
# 2003                                       34481
# 2004                                       33541
#
#                    International Security Identification Number Company Name  \
# Data Year - Fiscal
# 2000                                               DE0007100000   DAIMLER AG
# 2001                                               DE0007100000   DAIMLER AG
# 2002                                               DE0007100000   DAIMLER AG
# 2003                                               DE0007100000   DAIMLER AG
# 2004                                               DE0007100000   DAIMLER AG
#
#                    Active/Inactive Status Marker  \
# Data Year - Fiscal
# 2000                                           A
# 2001                                           A
# 2002                                           A
# 2003                                           A
# 2004                                           A
#
#                    Current ISO Country Code - Incorporation
# Data Year - Fiscal
# 2000                                                    DEU
# 2001                                                    DEU
# 2002                                                    DEU
# 2003                                                    DEU
# 2004                                                    DEU

# %%
#The number of the columns we do not want is indexed by the numbers in "loop_list"
loop_list = [0,1,2,3,4,5,11,13,14]
for i in car_data.columns[loop_list]:
    del car_data[i]

#We will also change the name of the columns so that the dataframe will be easier to work with. 
#To do this we use a dictionary
car_data = car_data.rename({"Data Year - Fiscal": "Fiscal Year",'Assets - Total': 'Total Assets', 'Earnings Before Interest': 'EBIT', 
                            'Income Before Extraordinary Items': 'Income', 'Revenue - Total': 'Total Revenue', 'Stockholders Equity - Parent': 
                            'Stockholders Equity'}, axis='columns')

#The data now looks like this
car_data.head()
# Out:
#                     Total Assets     EBIT  Income  Total Revenue  \
# Data Year - Fiscal
# 2000                      199274  17778.0    2465         162384
# 2001                      207410  12984.0    -662         152873
# 2002                      187327  17655.0    4877         149583
# 2003                      178268  15480.0    -418         136437
# 2004                      182696  15775.0    2466         142059
#
#                     Stockholders Equity Company Name
# Data Year - Fiscal
# 2000                              42409   DAIMLER AG
# 2001                              39004   DAIMLER AG
# 2002                              34914   DAIMLER AG
# 2003                              34481   DAIMLER AG
# 2004                              33541   DAIMLER AG

# %%
#SIMON WORKS HERE
daimler_data = car_data[0:18]
volkswagen_data = car_data[18:36]


#Now we need to calculate the key preformance measurement. 
#We create new columns for the numbers
daimler_data["EBIT Margin"] = daimler_data["EBIT"]/daimler_data["Total Revenue"]
daimler_data["ROA"] = daimler_data["Income"]/daimler_data["Total Assets"]
daimler_data["ROE"] = daimler_data["Income"]/daimler_data["Stockholders Equity"]
daimler_data

#now we do the same for volkswagen
volkswagen_data['EBIT Margin'] = volkswagen_data['EBIT'] / volkswagen_data['Total Revenue']
volkswagen_data['ROA'] = volkswagen_data['Income'] / volkswagen_data['Total Assets']
volkswagen_data['ROE'] = volkswagen_data['Income'] / volkswagen_data['Stockholders Equity']

#we have two different sets of the dataframe now so we can index our time series properly
#we do this by selecting a period range for the two data sets
dates_daimler = pd.period_range(start='2000', end='2017', freq='Y', name='Yearly Frequence')
daimler_data.index = dates_daimler


dates_volkswagen = pd.period_range(start='2000', end='2017', freq='Y', name='Yearly Frequence')

volkswagen_data.index = dates_volkswagen
# Out:
# /Users/gustaf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/gustaf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/gustaf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                     Total Assets     EBIT  Income  Total Revenue  \
# Data Year - Fiscal
# 2000                      199274  17778.0    2465         162384
# 2001                      207410  12984.0    -662         152873
# 2002                      187327  17655.0    4877         149583
# 2003                      178268  15480.0    -418         136437
# 2004                      182696  15775.0    2466         142059
# 2005                      201632   9713.0    2851         149776
# 2006                      190022   9061.0    3231         151499
# 2007                      135094  15408.0    4849          99399
# 2008                      132219  10761.0    1638          95873
# 2009                      128821   3279.0   -2640          78924
# 2010                      135830   9325.0    4498          97761
# 2011                      148132  10840.0    5667         106540
# 2012                      162978  10718.0    6095         114297
# 2013                      168518  10860.0    6842         117982
# 2014                      189635  13048.0    6962         129872
# 2015                      217166  16657.0    8424         149467
# 2016                      242988  16861.0    8526         153261
# 2017                      255605  17332.0   10525         164330
#
#                     Stockholders Equity Company Name  EBIT Margin       ROA  \
# Data Year - Fiscal
# 2000                              42409   DAIMLER AG     0.109481  0.012370
# 2001                              39004   DAIMLER AG     0.084933 -0.003192
# 2002                              34914   DAIMLER AG     0.118028  0.026035
# 2003                              34481   DAIMLER AG     0.113459 -0.002345
# 2004                              33541   DAIMLER AG     0.111045  0.013498
# 2005                              36449   DAIMLER AG     0.064850  0.014140
# 2006                              34155   DAIMLER AG     0.059809  0.017003
# 2007                              36718   DAIMLER AG     0.155012  0.035894
# 2008                              31216   DAIMLER AG     0.112242  0.012389
# 2009                              30261   DAIMLER AG     0.041546 -0.020494
# 2010                              36373   DAIMLER AG     0.095386  0.033115
# 2011                              39624   DAIMLER AG     0.101746  0.038256
# 2012                              43879   DAIMLER AG     0.093773  0.037398
# 2013                              42680   DAIMLER AG     0.092048  0.040601
# 2014                              43665   DAIMLER AG     0.100468  0.036713
# 2015                              53561   DAIMLER AG     0.111443  0.038791
# 2016                              57950   DAIMLER AG     0.110015  0.035088
# 2017                              64023   DAIMLER AG     0.105471  0.041177
#
#                          ROE
# Data Year - Fiscal
# 2000                0.058124
# 2001               -0.016973
# 2002                0.139686
# 2003               -0.012123
# 2004                0.073522
# 2005                0.078219
# 2006                0.094598
# 2007                0.132061
# 2008                0.052473
# 2009               -0.087241
# 2010                0.123663
# 2011                0.143019
# 2012                0.138905
# 2013                0.160309
# 2014                0.159441
# 2015                0.157279
# 2016                0.147127
# 2017                0.164394

# %%
#now we calculate an EBIT margin, ROA and ROE and add the columns to our chosen data frame
volkswagen_data['EBIT Margin'] = volkswagen_data['EBIT'] / volkswagen_data['Total Revenue']

volkswagen_data['ROA'] = volkswagen_data['Income'] / volkswagen_data['Total Assets']

volkswagen_data['ROE'] = volkswagen_data['Income'] / volkswagen_data['Stockholders Equity']

dates_daimler = pd.period_range(start='2000', end='2017', freq='Y', name='Yearly Frequence')

daimler_data.index = dates_daimler


dates_volkswagen = pd.period_range(start='2000', end='2017', freq='Y', name='Yearly Frequence')

volkswagen_data.index = dates_volkswagen
#daimler_data
# Out:
# /Users/gustaf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/gustaf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/gustaf/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.style.use('ggplot')

daimler_data['EBIT Margin'].plot(label = 'Daimler', legend = True)
volkswagen_data['EBIT Margin'].plot(label = 'Volkswagen', legend = True)
plt.ylabel('EBIT Margin')
# Out:
# Text(0,0.5,'EBIT Margin')

# %%
#TO HERE

# %%
#GUSTAF FROM HERE

# %%
car_data

# %%
#TO HERE

# %%
#LAWRANCE FORM HERE

# %%
#TO HERE

# %%
#CARINA FROM HERE

# %%
#TO HERE
