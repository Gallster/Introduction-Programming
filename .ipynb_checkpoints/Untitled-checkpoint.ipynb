# %% [markdown]
# Hello and welcome, work hard play hard

# %%
import numpy as np
import pandas as pd




car_data = pd.read_excel('data_daimler_volkswagen.xlsx')

car_data
# Out:
#     Global Company Key Industry Format Data Format  \
# 0                17828            INDL    HIST_STD
# 1                17828            INDL    HIST_STD
# 2                17828            INDL    HIST_STD
# 3                17828            INDL    HIST_STD
# 4                17828            INDL    HIST_STD
# 5                17828            INDL    HIST_STD
# 6                17828            INDL    HIST_STD
# 7                17828            INDL    HIST_STD
# 8                17828            INDL    HIST_STD
# 9                17828            INDL    HIST_STD
# 10               17828            INDL    HIST_STD
# 11               17828            INDL    HIST_STD
# 12               17828            INDL    HIST_STD
# 13               17828            INDL    HIST_STD
# 14               17828            INDL    HIST_STD
# 15               17828            INDL    HIST_STD
# 16               17828            INDL    HIST_STD
# ...
